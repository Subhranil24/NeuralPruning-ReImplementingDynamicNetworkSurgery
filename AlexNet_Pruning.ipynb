# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import torch.nn as nn
import torch
import torchvision
from torchvision import models, transforms
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR

import numpy as np
import random

# %matplotlib inline
import matplotlib.pyplot as plt

from copy import deepcopy

basepath = '/content/drive/My Drive/CS618_Project/ImageNet_AlexNet'

# %%
class EarlyStopping:
    def __init__(self, patience=7, filename='checkpoint_0', verbose=False):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.filename = filename

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose: print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(),basepath+'/CheckPoints/'+self.filename+'.pt')
        self.val_loss_min = val_loss

# %%
def get_data_loaders():
  transform = transforms.Compose([transforms.Resize((32,32)),transforms.ToTensor(),transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])
  cifar10_train = torchvision.datasets.CIFAR10('../data',transform=transform,train=True,download=True)
  cifar10_test = torchvision.datasets.CIFAR10('../data',transform=transform,train=False,download=True)
  data_loader_train = torch.utils.data.DataLoader(cifar10_train, batch_size=1024, shuffle=True, num_workers=8)
  data_loader_test = torch.utils.data.DataLoader(cifar10_test, batch_size=2048, shuffle=True, num_workers=8)
  return(data_loader_train,data_loader_test)

data_loader_train,data_loader_test = get_data_loaders()
# Out:
# 0it [00:00, ?it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
# 170500096it [00:02, 61133322.78it/s]
# Extracting ../data/cifar-10-python.tar.gz to ../data
# Files already downloaded and verified

# %%
def defineMasks():
  mask_conv1 = torch.ones(64,3,3,3)
  mask_conv2 = torch.ones(192,64,3,3)
  mask_conv3 = torch.ones(384,192,3,3)
  mask_conv4 = torch.ones(256,384,3,3)
  mask_conv5 = torch.ones(256,256,3,3)
  mask_linear1 = torch.ones(4096,256*2*2)
  mask_linear2 = torch.ones(4096,4096)
  mask_linear3 = torch.ones(10,4096)
  return mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3

# %%
class AlexNet(nn.Module):

    def __init__(self):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=2, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(64, 192, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 2 * 2, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, 10),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), 256 * 2 * 2)
        x = self.classifier(x)
        return x

# %%
num_classes = 10
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3 = defineMasks()

def get_unpruned_model(num_classes):
  model = AlexNet()
  return(model)

model = get_unpruned_model(num_classes)

# %%
def plot_losses(train_loss,test_loss,filename,i):
  x_axis = list(range(1,len(train_loss)+1))
  fig = plt.figure(i,figsize=(20,10))
  plt.axes(yscale='log')
  plt.plot(x_axis, train_loss, color='blue', label='Train Loss Loss')
  plt.plot(x_axis, test_loss, color='green', label='Validation Loss')
  plt.legend(loc=1)
  plt.xlabel('Iterations over entire dataset')
  plt.ylabel('Loss')
  plt.ylim(0.01,3)
  plt.savefig(basepath+'/Losses/'+filename+'.png')
  plt.close(fig)

def plot_accuracies(train_accuracy,test_accuracy,filename,i):
  x_axis = list(range(1,len(train_accuracy)+1))
  fig = plt.figure(i,figsize=(20,10))
  plt.yscale('log')
  plt.plot(x_axis, train_accuracy, color='blue', label='Train Accuracy')
  plt.plot(x_axis, test_accuracy, color='green', label='Validation Accuracy')
  plt.legend(loc=1)
  plt.xlabel('Iterations over entire dataset')
  plt.ylabel('Accuracy')
  plt.ylim(0.1,1)
  plt.savefig(basepath+'/Accuracies/'+filename+'.png')
  plt.close(fig)

# %%
def train(model,prune_itr,lr_multiplier=1):
  
  scale_factor = 16

  learning_rate = 1e-3*lr_multiplier; wt_dcy =1e-7; lr_patience = int(2000/scale_factor); lr_stepsize = int(3000/scale_factor); es_patience = int(5000/scale_factor)
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=wt_dcy)
  scheduler_plateau = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=lr_patience, verbose=True, threshold=1e-7)
  scheduler_stepLR = StepLR(optimizer, step_size=lr_stepsize, gamma=0.8)
  early_stopping = EarlyStopping(patience=es_patience,filename='checkpoint_'+str(prune_itr), verbose=True)

  torch.cuda.empty_cache()
  model = model.to(device)
  num_epochs = 50
  es_flag = 0

  train_loss = []; test_loss = []; train_accuracy = []; test_accuracy = []
  
  best_loss = 100000; best_accuracy = 2

  for epoch in range(num_epochs):
    
    correct = 0; data_size = 0; t_loss = 0
    
    for i, (images, labels) in enumerate(data_loader_train):

      model.train()
      images = images.to(device); labels = labels.to(device)
      data_size += len(images)
      outputs = torch.nn.functional.log_softmax(model(images), dim=1)
      trainloss = criterion(outputs,labels)
      optimizer.zero_grad()
      trainloss.backward()
      optimizer.step()
      _, predicted = torch.max(outputs.data, 1)
      correct += (predicted == labels).sum().item()
      t_loss += trainloss.item()
    
      correct_t = 0; data_size_t = 0; tt_loss = 0
      model.eval()
      with torch.no_grad():
        for images, labels in data_loader_test:
          images = images.to(device); labels = labels.to(device)
          data_size_t += len(images)
          outputs = torch.nn.functional.log_softmax(model(images), dim=1)
          _, predicted = torch.max(outputs.data, 1)
          correct_t += (predicted == labels).sum().item()
          tt_loss += criterion(outputs, labels).item()
      print('Epoch: {}, Batch: {}, Train Loss: {:.3f} Train Accuracy: {:.3f}%, Validation Loss: {:.3f} Validation Accuracy: {:.3f}%'.
            format(epoch+1, i+1, trainloss.item(), 100*(predicted==labels).sum().item()/len(images), tt_loss/len(data_loader_test), 100*correct_t/data_size_t))
      
      train_loss.append(trainloss.item()); test_loss.append(tt_loss/len(data_loader_test))
      train_accuracy.append((predicted==labels).sum().item()/len(images)); test_accuracy.append(correct_t/data_size_t)
      
      if (tt_loss/len(data_loader_test)) < best_loss:
        best_loss = tt_loss/len(data_loader_test)
        best_accuracy = correct_t/data_size_t
        

      scheduler_stepLR.step()
      scheduler_plateau.step(tt_loss/len(data_loader_test))

      early_stopping(tt_loss/len(data_loader_test), model)
      if early_stopping.early_stop:
        print("Early stopping")
        es_flag = 1
        break
    if es_flag == 1: break
  
  model.load_state_dict(torch.load(basepath+'/CheckPoints/'+'checkpoint_'+str(prune_itr)+'.pt'))

  return(model,train_loss,test_loss,train_accuracy,test_accuracy,best_loss,best_accuracy)

# %%
lr_multiplier = 1
dict_best_info = {}
#4model.load_state_dict(torch.load(basepath+'/CheckPoints/'+'checkpoint_0.pt'))
model,train_loss,test_loss,train_accuracy,test_accuracy,best_loss,best_accuracy = train(model,0,lr_multiplier)
dict_best_info[0] = (best_loss,best_accuracy)
plot_losses(train_loss,test_loss,'l0',1)
plot_accuracies(train_accuracy,test_accuracy,'a0',2)

model.load_state_dict(torch.load(basepath+'/CheckPoints/'+'checkpoint_0.pt'))
model = model.to(device)
print(model)

print('Best Accuracy is ' + str(round(best_accuracy*100,2)))
print('Best Loss is ' + str(round(best_loss,3)))
# Out:
# Epoch: 1, Batch: 1, Train Loss: 2.303 Train Accuracy: 8.684%, Validation Loss: 2.359 Validation Accuracy: 10.000%
# Validation loss decreased (inf --> 2.359358).  Saving model ...
# Epoch: 1, Batch: 2, Train Loss: 2.389 Train Accuracy: 9.624%, Validation Loss: 2.304 Validation Accuracy: 10.000%
# Validation loss decreased (2.359358 --> 2.303862).  Saving model ...
# Epoch: 1, Batch: 3, Train Loss: 2.301 Train Accuracy: 9.790%, Validation Loss: 2.306 Validation Accuracy: 10.000%
# EarlyStopping counter: 1 out of 312
# Epoch: 1, Batch: 4, Train Loss: 2.306 Train Accuracy: 11.117%, Validation Loss: 2.305 Validation Accuracy: 10.000%
# EarlyStopping counter: 2 out of 312
# Epoch: 1, Batch: 5, Train Loss: 2.309 Train Accuracy: 15.210%, Validation Loss: 2.303 Validation Accuracy: 15.200%
# Validation loss decreased (2.303862 --> 2.303155).  Saving model ...
# Epoch: 1, Batch: 6, Train Loss: 2.299 Train Accuracy: 15.100%, Validation Loss: 2.300 Validation Accuracy: 14.140%
# Validation loss decreased (2.303155 --> 2.300321).  Saving model ...
# Epoch: 1, Batch: 7, Train Loss: 2.301 Train Accuracy: 13.662%, Validation Loss: 2.295 Validation Accuracy: 14.280%
# Validation loss decreased (2.300321 --> 2.294746).  Saving model ...
# Epoch: 1, Batch: 8, Train Loss: 2.295 Train Accuracy: 15.044%, Validation Loss: 2.282 Validation Accuracy: 14.420%
# Validation loss decreased (2.294746 --> 2.281961).  Saving model ...
# Epoch: 1, Batch: 9, Train Loss: 2.288 Train Accuracy: 15.929%, Validation Loss: 2.253 Validation Accuracy: 15.250%
# EarlyStopping counter: 307 out of 312
# Epoch: 15, Batch: 13, Train Loss: 0.171 Train Accuracy: 67.091%, Validation Loss: 1.418 Validation Accuracy: 67.930%
# EarlyStopping counter: 308 out of 312
# Epoch: 15, Batch: 14, Train Loss: 0.209 Train Accuracy: 66.980%, Validation Loss: 1.383 Validation Accuracy: 68.480%
# EarlyStopping counter: 309 out of 312
# Epoch: 15, Batch: 15, Train Loss: 0.201 Train Accuracy: 68.418%, Validation Loss: 1.402 Validation Accuracy: 68.180%
# EarlyStopping counter: 310 out of 312
# Epoch: 15, Batch: 16, Train Loss: 0.199 Train Accuracy: 69.635%, Validation Loss: 1.372 Validation Accuracy: 68.580%
# EarlyStopping counter: 311 out of 312
# Epoch: 15, Batch: 17, Train Loss: 0.187 Train Accuracy: 69.635%, Validation Loss: 1.393 Validation Accuracy: 67.990%
# EarlyStopping counter: 312 out of 312
# Early stopping
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=1024, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )
# Best Accuracy is 67.66
# Best Loss is 0.938

# %%
def get_model_layerwise_analysis(model):

  for layer, (name, module) in enumerate(model.features._modules.items()):
    if name == '0':
      weights = torch.abs(module.weight).cpu()
      print(weights.max(),weights.mean(),weights.std())
    if name == '3':
      weights = torch.abs(module.weight).cpu()
      print(weights.max(),weights.mean(),weights.std())
    if name == '6':
      weights = torch.abs(module.weight).cpu()
      print(weights.max(),weights.mean(),weights.std())
    if name == '8':
      weights = torch.abs(module.weight).cpu()
      print(weights.max(),weights.mean(),weights.std())
    if name == '10':
      weights = torch.abs(module.weight).cpu()
      print(weights.max(),weights.mean(),weights.std())

  for layer, (name, module) in enumerate(model.classifier._modules.items()):
    if name == '1':
      weights = torch.abs(module.weight).cpu()
      print(weights.max(),weights.mean(),weights.std())
    if name == '4':
      weights = torch.abs(module.weight).cpu()
      print(weights.max(),weights.mean(),weights.std())
    if name == '6':
      weights = torch.abs(module.weight).cpu()
      print(weights.max(),weights.mean(),weights.std())

get_model_layerwise_analysis(model)
# Out:
# tensor(0.1923, grad_fn=<MaxBackward1>) tensor(0.0977, grad_fn=<MeanBackward0>) tensor(0.0562, grad_fn=<StdBackward0>)
# tensor(0.0417, grad_fn=<MaxBackward1>) tensor(0.0208, grad_fn=<MeanBackward0>) tensor(0.0120, grad_fn=<StdBackward0>)
# tensor(0.0241, grad_fn=<MaxBackward1>) tensor(0.0120, grad_fn=<MeanBackward0>) tensor(0.0069, grad_fn=<StdBackward0>)
# tensor(0.0170, grad_fn=<MaxBackward1>) tensor(0.0085, grad_fn=<MeanBackward0>) tensor(0.0049, grad_fn=<StdBackward0>)
# tensor(0.0208, grad_fn=<MaxBackward1>) tensor(0.0104, grad_fn=<MeanBackward0>) tensor(0.0060, grad_fn=<StdBackward0>)
# tensor(0.0312, grad_fn=<MaxBackward1>) tensor(0.0156, grad_fn=<MeanBackward0>) tensor(0.0090, grad_fn=<StdBackward0>)
# tensor(0.0156, grad_fn=<MaxBackward1>) tensor(0.0078, grad_fn=<MeanBackward0>) tensor(0.0045, grad_fn=<StdBackward0>)
# tensor(0.0156, grad_fn=<MaxBackward1>) tensor(0.0078, grad_fn=<MeanBackward0>) tensor(0.0045, grad_fn=<StdBackward0>)

# %%
initial_parameters = sum([p.numel() for p in model.parameters()])

# %%
def count_nonzeros(model):
  nonzeros = 0
  for param in model.parameters():
    if param is not None: nonzeros += torch.sum((param != 0).int()).item()
  return(nonzeros)

# %%
def update_masks(model, mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3, k1, k2, k3, k4, k5, k6, k7, k8):
    
  for layer, (name, module) in enumerate(model.features._modules.items()):
    if name == '0':
      a_c1 = 0.17*torch.abs(module.weight.max()).data * k1
      t_c1 = 1*torch.abs(module.weight.std()).data
      b_c1 = a_c1 + t_c1
    if name == '3':
      a_c2 = 0.2*torch.abs(module.weight.max()).data * k2
      t_c2 = 2*torch.abs(module.weight.std()).data
      b_c2 = a_c2 + t_c2
    if name == '6':
      a_c3 = 0.2*torch.abs(module.weight.max()).data * k3
      t_c3 = 2*torch.abs(module.weight.std()).data
      b_c3 = a_c3 + t_c3
    if name == '8':
      a_c4 = 0.25*torch.abs(module.weight.max()).data * k4
      t_c4 = 2*torch.abs(module.weight.std()).data
      b_c4 = a_c4 + t_c4
    if name == '10':
      a_c5 = 0.25*torch.abs(module.weight.max()).data * k5
      t_c5 = 2*torch.abs(module.weight.std()).data
      b_c5 = a_c5 + t_c5
  
  for layer, (name, module) in enumerate(model.classifier._modules.items()):
    if name == '1':
      a_l1 = 0.35*torch.abs(module.weight.max()).data * k6
      t_l1 = 2*torch.abs(module.weight.std()).data
      b_l1 = a_l1 + t_l1
    if name == '4':
      a_l2 = 0.25*torch.abs(module.weight.max()).data * k7
      t_l2 = 1*torch.abs(module.weight.std()).data
      b_l2 = a_l2 + t_l2
    if name == '6':
      a_l3 = 0.2*torch.abs(module.weight.max()).data * k8
      t_l3 = 1*torch.abs(module.weight.std()).data
      b_l3 = a_l3 + t_l3
  
  for layer, (name, module) in enumerate(model.features._modules.items()):
    if name == '0':
      weights = torch.abs(module.weight).cpu()
      temp_mask1 = (weights > b_c1).float() * 1; temp_mask2 = (weights > a_c1).float() * 1
      temp_mask = (temp_mask2 * mask_conv1) + temp_mask1
      mask_conv1 = (temp_mask >= 1.).float() * 1
    if name == '3':
      weights = torch.abs(module.weight).cpu()
      temp_mask1 = (weights > b_c2).float() * 1; temp_mask2 = (weights > a_c2).float() * 1
      temp_mask = (temp_mask2 * mask_conv2) + temp_mask1
      mask_conv2 = (temp_mask >= 1.).float() * 1
    if name == '6':
      weights = torch.abs(module.weight).cpu()
      temp_mask1 = (weights > b_c3).float() * 1; temp_mask2 = (weights > a_c3).float() * 1
      temp_mask = (temp_mask2 * mask_conv3) + temp_mask1
      mask_conv3 = (temp_mask >= 1.).float() * 1
    if name == '8':
      weights = torch.abs(module.weight).cpu()
      temp_mask1 = (weights > b_c4).float() * 1; temp_mask2 = (weights > a_c4).float() * 1
      temp_mask = (temp_mask2 * mask_conv4) + temp_mask1
      mask_conv4 = (temp_mask >= 1.).float() * 1
    if name == '10':
      weights = torch.abs(module.weight).cpu()
      temp_mask1 = (weights > b_c5).float() * 1; temp_mask2 = (weights > a_c5).float() * 1
      temp_mask = (temp_mask2 * mask_conv5) + temp_mask1
      mask_conv5 = (temp_mask >= 1.).float() * 1

    
  for layer, (name, module) in enumerate(model.classifier._modules.items()):
    if name == '1':
      weights = torch.abs(module.weight).cpu()
      temp_mask1 = (weights > b_l1).float() * 1; temp_mask2 = (weights > a_l1).float() * 1
      temp_mask = (temp_mask2 * mask_linear1) + temp_mask1
      mask_linear1 = (temp_mask >= 1.).float() * 1
    if name == '4':
      weights = torch.abs(module.weight).cpu()
      temp_mask1 = (weights > b_l2).float() * 1; temp_mask2 = (weights > a_l2).float() * 1
      temp_mask = (temp_mask2 * mask_linear2) + temp_mask1
      mask_linear2 = (temp_mask >= 1.).float() * 1
    if name == '6':
      weights = torch.abs(module.weight).cpu()
      temp_mask1 = (weights > b_l3).float() * 1; temp_mask2 = (weights > a_l3).float() * 1
      temp_mask = (temp_mask2 * mask_linear3) + temp_mask1
      mask_linear3 = (temp_mask >= 1.).float() * 1


  return mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3

# %%
def model_surgery(model, mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3):

  for layer, (name, module) in enumerate(model.features._modules.items()):
    if name == '0':
      weights = (module.weight.data) * mask_conv1.to(device)
      model.features._modules[name].weight.data = weights.to(device)
    if name == '3':
      weights = (module.weight.data) * mask_conv2.to(device)
      model.features._modules[name].weight.data = weights.to(device)
    if name == '6':
      weights = (module.weight.data) * mask_conv3.to(device)
      model.features._modules[name].weight.data = weights.to(device)
    if name == '8':
      weights = (module.weight.data) * mask_conv4.to(device)
      model.features._modules[name].weight.data = weights.to(device)
    if name == '10':
      weights = (module.weight.data) * mask_conv5.to(device)
      model.features._modules[name].weight.data = weights.to(device)
  
  for layer, (name, module) in enumerate(model.classifier._modules.items()):
    if name == '1':
      weights = (module.weight.data) * mask_linear1.to(device)
      model.classifier._modules[name].weight.data = weights.to(device)
    if name == '4':
      weights = (module.weight.data) * mask_linear2.to(device)
      model.classifier._modules[name].weight.data = weights.to(device)
    if name == '6':
      weights = (module.weight.data) * mask_linear3.to(device)
      model.classifier._modules[name].weight.data = weights.to(device)

  for param in model.parameters(): param.requires_grad = True
  
  return(model)

# %%
def perform_surgery_training(model, prune_itr, lr_multiplier, mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3):
  
  scale_factor = 16

  learning_rate = 1e-3*lr_multiplier; wt_dcy =1e-7; lr_patience = int(2000/scale_factor); lr_stepsize = 1; es_patience = int(10000/scale_factor)
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=wt_dcy)
  scheduler_plateau = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=lr_patience, verbose=True, threshold=1e-7)
  scheduler_stepLR = StepLR(optimizer, step_size=lr_stepsize, gamma=0.995)
  early_stopping = EarlyStopping(patience=es_patience,filename='checkpoint_'+str(prune_itr), verbose=True)

  torch.cuda.empty_cache()
  model = model.to(device)
  num_epochs = 70
  es_flag = 0

  final_model = deepcopy(model)

  train_loss = []; test_loss = []; train_accuracy = []; test_accuracy = []

  nonzero_parameter_list = []
  
  best_loss = 100000; best_accuracy = 2; best_parameter_size = 0

  prob_itr = 0; prob_threshold = 1.0; k1 = 1; k2 = 1; k3 = 1; k4 = 1; k5 = 1; k6 = 1; k7 = 1; k8 = 1

  for epoch in range(num_epochs):
    
    correct = 0; data_size = 0; t_loss = 0
    
    for i, (images, labels) in enumerate(data_loader_train):

      model.train()
      images = images.to(device); labels = labels.to(device)
      data_size += len(images)
      outputs = torch.nn.functional.log_softmax(model(images), dim=1)
      trainloss = criterion(outputs,labels)
      optimizer.zero_grad()
      trainloss.backward()

      choice = random.random()
      if choice <= prob_threshold:
        print('Performing Surgery for choice as ' + str(round(choice,4)) + ' for threshold ' + str(round(prob_threshold,4)) + '.')
        mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3 = update_masks(model,mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3, k1, k2, k3, k4, k5, k6, k7, k8)
        k1 = k1 * 1.00015; k2 = k2 * 1.00014; k3 = k3 * 1.0001; k4 = k4 * 1.0001; k5 = k5 * 1.0001; k6 = k6 * 1.00007; k7 = k7 * 1.00012; k8 = k8 * 1.0009

      optimizer.step()
      model = model_surgery(model, mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3)

      prob_itr += 1
      prob_threshold *= 0.9993
      nonzero_parameters = count_nonzeros(model)
      nonzero_parameter_list.append(nonzero_parameters)
      print('Parameters are: ' + str(nonzero_parameters))
      
      _, predicted = torch.max(outputs.data, 1)
      correct += (predicted == labels).sum().item()
      t_loss += trainloss.item()
    
      correct_t = 0; data_size_t = 0; tt_loss = 0

      model.eval()
      with torch.no_grad():
        for images, labels in data_loader_test:
          images = images.to(device); labels = labels.to(device)
          data_size_t += len(images)
          outputs = torch.nn.functional.log_softmax(model(images), dim=1)
          _, predicted = torch.max(outputs.data, 1)
          correct_t += (predicted == labels).sum().item()
          tt_loss += criterion(outputs, labels).item()
      print('Epoch: {}, Batch: {}, Train Loss: {:.3f} Train Accuracy: {:.3f}%, Validation Loss: {:.3f} Validation Accuracy: {:.3f}%'.
            format(epoch+1, i+1, trainloss.item(), 100*(predicted==labels).sum().item()/len(images), tt_loss/len(data_loader_test), 100*correct_t/data_size_t))
      
      train_loss.append(trainloss.item()); test_loss.append(tt_loss/len(data_loader_test))
      train_accuracy.append((predicted==labels).sum().item()/len(images)); test_accuracy.append(correct_t/data_size_t)
      
      if (tt_loss/len(data_loader_test)) < best_loss:
        best_loss = tt_loss/len(data_loader_test)
        best_accuracy = correct_t/data_size_t
        best_parameter_size = nonzero_parameters
        
      scheduler_stepLR.step()
      scheduler_plateau.step(tt_loss/len(data_loader_test))

      early_stopping(tt_loss/len(data_loader_test), model)
      if early_stopping.early_stop:
        print("Early stopping")
        es_flag = 1
        break
    if es_flag == 1: break

  if (correct_t/data_size_t) >= (best_accuracy-(0.1*best_accuracy)):
    last_loss = tt_loss/len(data_loader_test)
    last_accuracy = correct_t/data_size_t
    last_parameter_size = nonzero_parameters
    final_model = deepcopy(model)

  model.load_state_dict(torch.load(basepath+'/CheckPoints/'+'checkpoint_'+str(prune_itr)+'.pt'))

  return(model, final_model, train_loss, test_loss, train_accuracy, test_accuracy, best_loss, best_accuracy, best_parameter_size, last_loss, last_accuracy, last_parameter_size, nonzero_parameter_list)

# %%
def plot_parameters(parameter_list,filename,i):
  x_axis = list(range(1,len(parameter_list)+1))
  fig = plt.figure(i,figsize=(20,10))
  plt.plot(x_axis, parameter_list, color='blue', label='Total Parameters')
  plt.legend(loc=1)
  plt.xlabel('Iterations over entire dataset')
  plt.ylabel('Parameters')
  plt.ylim(0,70000)
  plt.savefig(basepath+'/Parameters/'+filename+'.png')
  plt.close(fig)

# %%
mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3 = defineMasks()
lr_multiplier = 1
new_model = deepcopy(model)
#new_model.load_state_dict(torch.load(basepath+'/CheckPoints/'+'checkpoint_1.pt'))
pruned_model, final_model, train_loss, test_loss, train_accuracy, test_accuracy, best_loss, best_accuracy, best_parameter_size, last_loss, last_accuracy, last_parameter_size, parameter_list = perform_surgery_training(new_model,1,lr_multiplier,mask_conv1, mask_conv2, mask_conv3, mask_conv4, mask_conv5, mask_linear1, mask_linear2, mask_linear3)
dict_best_info[1] = (best_loss,best_accuracy)
plot_losses(train_loss,test_loss,'l1',1)
plot_accuracies(train_accuracy,test_accuracy,'a1',2)
plot_parameters(parameter_list,'p1',3)

pruned_model.load_state_dict(torch.load(basepath+'/CheckPoints/'+'checkpoint_1.pt'))
pruned_model = pruned_model.to(device)
print(pruned_model)
# Out:
# Performing Surgery for choice as 0.0625 for threshold 1.0.
# Parameters are: 582315
# Epoch: 1, Batch: 1, Train Loss: 0.604 Train Accuracy: 15.597%, Validation Loss: 2.377 Validation Accuracy: 15.000%
# Validation loss decreased (inf --> 2.377323).  Saving model ...
# Performing Surgery for choice as 0.1132 for threshold 0.9993.
# Parameters are: 555341
# Epoch: 1, Batch: 2, Train Loss: 2.371 Train Accuracy: 13.772%, Validation Loss: 2.339 Validation Accuracy: 12.550%
# Validation loss decreased (2.377323 --> 2.338890).  Saving model ...
# Performing Surgery for choice as 0.8575 for threshold 0.9986.
# Parameters are: 541778
# Epoch: 1, Batch: 3, Train Loss: 2.345 Train Accuracy: 11.781%, Validation Loss: 2.276 Validation Accuracy: 12.220%
# Validation loss decreased (2.338890 --> 2.275935).  Saving model ...
# Performing Surgery for choice as 0.9917 for threshold 0.9979.
# Parameters are: 525235
# Epoch: 1, Batch: 4, Train Loss: 2.281 Train Accuracy: 21.571%, Validation Loss: 2.229 Validation Accuracy: 21.420%
# Validation loss decreased (2.275935 --> 2.229045).  Saving model ...
# Performing Surgery for choice as 0.4321 for threshold 0.9972.
# Parameters are: 511653
# Epoch: 1, Batch: 5, Train Loss: 2.226 Train Accuracy: 14.491%, Validation Loss: 2.213 Validation Accuracy: 13.570%
# Validation loss decreased (2.229045 --> 2.212629).  Saving model ...
# Performing Surgery for choice as 0.9832 for threshold 0.9965.
# Parameters are: 499957
# Epoch: 1, Batch: 6, Train Loss: 2.213 Train Accuracy: 16.316%, Validation Loss: 2.197 Validation Accuracy: 15.780%
# Validation loss decreased (2.212629 --> 2.196767).  Saving model ...
# Performing Surgery for choice as 0.9339 for threshold 0.9958.
# Parameters are: 490426
# Epoch: 1, Batch: 7, Train Loss: 2.206 Train Accuracy: 22.013%, Validation Loss: 2.172 Validation Accuracy: 21.800%
# Validation loss decreased (2.196767 --> 2.171819).  Saving model ...
# Performing Surgery for choice as 0.046 for threshold 0.9951.
# Parameters are: 482480
# Epoch: 1, Batch: 8, Train Loss: 2.179 Train Accuracy: 26.549%, Validation Loss: 2.135 Validation Accuracy: 26.240%
# Validation loss decreased (2.171819 --> 2.134662).  Saving model ...
# Performing Surgery for choice as 0.0587 for threshold 0.9944.
# Parameters are: 475450
# Epoch: 1, Batch: 9, Train Loss: 2.142 Train Accuracy: 29.093%, Validation Loss: 2.093 Validation Accuracy: 28.600%
# Validation loss decreased (2.134662 --> 2.092573).  Saving model ...
# Performing Surgery for choice as 0.2307 for threshold 0.9937.
# Parameters are: 468896
# Epoch: 1, Batch: 10, Train Loss: 2.080 Train Accuracy: 30.420%, Validation Loss: 2.047 Validation Accuracy: 31.370%
# Validation loss decreased (2.092573 --> 2.046769).  Saving model ...
# Performing Surgery for choice as 0.8863 for threshold 0.993.
# Parameters are: 462816
# Epoch: 1, Batch: 11, Train Loss: 2.065 Train Accuracy: 34.403%, Validation Loss: 1.999 Validation Accuracy: 34.670%
# Validation loss decreased (2.046769 --> 1.998748).  Saving model ...
# Performing Surgery for choice as 0.357 for threshold 0.9923.
# Parameters are: 457014
# Epoch: 1, Batch: 12, Train Loss: 2.019 Train Accuracy: 33.794%, Validation Loss: 1.951 Validation Accuracy: 35.300%
# Validation loss decreased (1.998748 --> 1.950703).  Saving model ...
# Performing Surgery for choice as 0.7822 for threshold 0.9916.
# Parameters are: 451279
# Epoch: 1, Batch: 13, Train Loss: 1.974 Train Accuracy: 37.611%, Validation Loss: 1.905 Validation Accuracy: 35.430%
# Validation loss decreased (1.950703 --> 1.904590).  Saving model ...
# Performing Surgery for choice as 0.8014 for threshold 0.9909.
# Parameters are: 446203
# Epoch: 1, Batch: 14, Train Loss: 1.930 Train Accuracy: 36.504%, Validation Loss: 1.865 Validation Accuracy: 35.850%
# Validation loss decreased (1.904590 --> 1.864692).  Saving model ...
# Performing Surgery for choice as 0.9534 for threshold 0.9902.
# Parameters are: 441491
# Epoch: 1, Batch: 15, Train Loss: 1.843 Train Accuracy: 35.675%, Validation Loss: 1.824 Validation Accuracy: 36.550%
# Validation loss decreased (1.864692 --> 1.823970).  Saving model ...
# Performing Surgery for choice as 0.5876 for threshold 0.9896.
# Parameters are: 437453
# Epoch: 1, Batch: 16, Train Loss: 1.884 Train Accuracy: 39.270%, Validation Loss: 1.773 Validation Accuracy: 38.440%
# Validation loss decreased (1.823970 --> 1.773111).  Saving model ...
# Performing Surgery for choice as 0.5992 for threshold 0.9889.
# Parameters are: 434167
# Epoch: 1, Batch: 17, Train Loss: 1.824 Train Accuracy: 42.091%, Validation Loss: 1.721 Validation Accuracy: 40.780%
# Validation loss decreased (1.773111 --> 1.721059).  Saving model ...
# Performing Surgery for choice as 0.9191 for threshold 0.9882.
# Parameters are: 430944
# Epoch: 1, Batch: 18, Train Loss: 1.705 Train Accuracy: 43.473%, Validation Loss: 1.688 Validation Accuracy: 41.970%
# Validation loss decreased (1.721059 --> 1.688197).  Saving model ...
# Performing Surgery for choice as 0.2361 for threshold 0.9875.
# Parameters are: 427841
# Epoch: 1, Batch: 19, Train Loss: 1.664 Train Accuracy: 41.040%, Validation Loss: 1.683 Validation Accuracy: 41.520%
# Validation loss decreased (1.688197 --> 1.683032).  Saving model ...
# Performing Surgery for choice as 0.329 for threshold 0.9868.
# Parameters are: 424782
# Epoch: 1, Batch: 20, Train Loss: 1.706 Train Accuracy: 42.035%, Validation Loss: 1.651 Validation Accuracy: 42.270%
# Validation loss decreased (1.683032 --> 1.650672).  Saving model ...
# Performing Surgery for choice as 0.2483 for threshold 0.9861.
# Parameters are: 421998
# Epoch: 1, Batch: 21, Train Loss: 1.688 Train Accuracy: 44.027%, Validation Loss: 1.597 Validation Accuracy: 43.600%
# Validation loss decreased (1.650672 --> 1.597438).  Saving model ...
# Performing Surgery for choice as 0.164 for threshold 0.9854.
# Parameters are: 419402
# Epoch: 1, Batch: 22, Train Loss: 1.583 Train Accuracy: 41.814%, Validation Loss: 1.572 Validation Accuracy: 43.680%
# Validation loss decreased (1.597438 --> 1.572243).  Saving model ...
# Performing Surgery for choice as 0.2738 for threshold 0.9847.
# Parameters are: 416747
# Epoch: 1, Batch: 23, Train Loss: 1.585 Train Accuracy: 44.801%, Validation Loss: 1.539 Validation Accuracy: 44.070%
# Validation loss decreased (1.572243 --> 1.539327).  Saving model ...
# Performing Surgery for choice as 0.5426 for threshold 0.984.
# Parameters are: 413723
# Epoch: 1, Batch: 24, Train Loss: 1.569 Train Accuracy: 46.515%, Validation Loss: 1.511 Validation Accuracy: 45.790%
# Validation loss decreased (1.539327 --> 1.510833).  Saving model ...
# Performing Surgery for choice as 0.9808 for threshold 0.9833.
# Parameters are: 410916
# Epoch: 1, Batch: 25, Train Loss: 1.543 Train Accuracy: 46.681%, Validation Loss: 1.520 Validation Accuracy: 45.570%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.7692 for threshold 0.9826.
# Parameters are: 408244
# Epoch: 1, Batch: 26, Train Loss: 1.557 Train Accuracy: 45.741%, Validation Loss: 1.488 Validation Accuracy: 46.030%
# Validation loss decreased (1.510833 --> 1.487648).  Saving model ...
# Performing Surgery for choice as 0.9398 for threshold 0.982.
# Parameters are: 405922
# Epoch: 1, Batch: 27, Train Loss: 1.489 Train Accuracy: 47.898%, Validation Loss: 1.457 Validation Accuracy: 47.110%
# Validation loss decreased (1.487648 --> 1.457500).  Saving model ...
# Performing Surgery for choice as 0.1452 for threshold 0.9813.
# Parameters are: 403972
# Epoch: 1, Batch: 28, Train Loss: 1.486 Train Accuracy: 48.894%, Validation Loss: 1.428 Validation Accuracy: 48.130%
# Validation loss decreased (1.457500 --> 1.427953).  Saving model ...
# Performing Surgery for choice as 0.5895 for threshold 0.9806.
# Parameters are: 402136
# Epoch: 1, Batch: 29, Train Loss: 1.456 Train Accuracy: 47.400%, Validation Loss: 1.408 Validation Accuracy: 48.970%
# Validation loss decreased (1.427953 --> 1.408123).  Saving model ...
# Performing Surgery for choice as 0.756 for threshold 0.9799.
# Parameters are: 400347
# Epoch: 1, Batch: 30, Train Loss: 1.448 Train Accuracy: 48.451%, Validation Loss: 1.446 Validation Accuracy: 47.440%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.5286 for threshold 0.9792.
# Parameters are: 398659
# Epoch: 1, Batch: 31, Train Loss: 1.460 Train Accuracy: 47.124%, Validation Loss: 1.423 Validation Accuracy: 48.340%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.0389 for threshold 0.9785.
# Parameters are: 396903
# Epoch: 1, Batch: 32, Train Loss: 1.497 Train Accuracy: 50.774%, Validation Loss: 1.369 Validation Accuracy: 49.760%
# Validation loss decreased (1.408123 --> 1.369297).  Saving model ...
# Performing Surgery for choice as 0.4171 for threshold 0.9778.
# Parameters are: 395001
# Epoch: 1, Batch: 33, Train Loss: 1.402 Train Accuracy: 48.673%, Validation Loss: 1.387 Validation Accuracy: 48.660%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.4765 for threshold 0.9772.
# Parameters are: 393096
# Epoch: 1, Batch: 34, Train Loss: 1.432 Train Accuracy: 48.451%, Validation Loss: 1.408 Validation Accuracy: 48.620%
# EarlyStopping counter: 2 out of 625
# Parameters are: 393096
# Epoch: 1, Batch: 35, Train Loss: 1.414 Train Accuracy: 50.719%, Validation Loss: 1.369 Validation Accuracy: 50.730%
# Validation loss decreased (1.369297 --> 1.368729).  Saving model ...
# Performing Surgery for choice as 0.3468 for threshold 0.9758.
# Parameters are: 389768
# Epoch: 1, Batch: 36, Train Loss: 1.409 Train Accuracy: 52.987%, Validation Loss: 1.339 Validation Accuracy: 52.110%
# Validation loss decreased (1.368729 --> 1.338802).  Saving model ...
# Performing Surgery for choice as 0.5721 for threshold 0.9751.
# Parameters are: 388275
# Epoch: 1, Batch: 37, Train Loss: 1.401 Train Accuracy: 52.821%, Validation Loss: 1.331 Validation Accuracy: 51.730%
# Validation loss decreased (1.338802 --> 1.331067).  Saving model ...
# Performing Surgery for choice as 0.1563 for threshold 0.9744.
# Parameters are: 386842
# Epoch: 1, Batch: 38, Train Loss: 1.343 Train Accuracy: 49.613%, Validation Loss: 1.357 Validation Accuracy: 50.640%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.0953 for threshold 0.9737.
# Parameters are: 385451
# Epoch: 1, Batch: 39, Train Loss: 1.419 Train Accuracy: 50.996%, Validation Loss: 1.358 Validation Accuracy: 50.900%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.2001 for threshold 0.9731.
# Parameters are: 384478
# Epoch: 1, Batch: 40, Train Loss: 1.356 Train Accuracy: 52.987%, Validation Loss: 1.314 Validation Accuracy: 52.670%
# Validation loss decreased (1.331067 --> 1.313990).  Saving model ...
# Performing Surgery for choice as 0.4239 for threshold 0.9724.
# Parameters are: 383534
# Epoch: 1, Batch: 41, Train Loss: 1.303 Train Accuracy: 55.199%, Validation Loss: 1.287 Validation Accuracy: 53.790%
# Validation loss decreased (1.313990 --> 1.286709).  Saving model ...
# Performing Surgery for choice as 0.3015 for threshold 0.9717.
# Parameters are: 382588
# Epoch: 1, Batch: 42, Train Loss: 1.336 Train Accuracy: 52.378%, Validation Loss: 1.299 Validation Accuracy: 53.040%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.4586 for threshold 0.971.
# Parameters are: 381749
# Epoch: 1, Batch: 43, Train Loss: 1.328 Train Accuracy: 50.940%, Validation Loss: 1.303 Validation Accuracy: 53.230%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.2056 for threshold 0.9703.
# Parameters are: 380941
# Epoch: 1, Batch: 44, Train Loss: 1.258 Train Accuracy: 55.973%, Validation Loss: 1.306 Validation Accuracy: 53.700%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.566 for threshold 0.9697.
# Parameters are: 380256
# Epoch: 1, Batch: 45, Train Loss: 1.287 Train Accuracy: 53.374%, Validation Loss: 1.318 Validation Accuracy: 53.410%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.2618 for threshold 0.969.
# Parameters are: 379543
# Epoch: 1, Batch: 46, Train Loss: 1.332 Train Accuracy: 56.361%, Validation Loss: 1.284 Validation Accuracy: 54.090%
# Validation loss decreased (1.286709 --> 1.284125).  Saving model ...
# Parameters are: 379543
# Epoch: 1, Batch: 47, Train Loss: 1.297 Train Accuracy: 54.923%, Validation Loss: 1.252 Validation Accuracy: 54.550%
# Validation loss decreased (1.284125 --> 1.251976).  Saving model ...
# Performing Surgery for choice as 0.4794 for threshold 0.9676.
# Parameters are: 378197
# Epoch: 1, Batch: 48, Train Loss: 1.249 Train Accuracy: 52.765%, Validation Loss: 1.266 Validation Accuracy: 53.710%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.8924 for threshold 0.9669.
# Parameters are: 377447
# Epoch: 1, Batch: 49, Train Loss: 1.271 Train Accuracy: 52.710%, Validation Loss: 1.280 Validation Accuracy: 53.170%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.1473 for threshold 0.9663.
# Parameters are: 376588
# Epoch: 2, Batch: 1, Train Loss: 1.207 Train Accuracy: 52.765%, Validation Loss: 1.274 Validation Accuracy: 53.220%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.1893 for threshold 0.9656.
# Parameters are: 375682
# Epoch: 2, Batch: 2, Train Loss: 1.290 Train Accuracy: 56.195%, Validation Loss: 1.241 Validation Accuracy: 54.330%
# Validation loss decreased (1.251976 --> 1.241262).  Saving model ...
# Performing Surgery for choice as 0.523 for threshold 0.9649.
# Parameters are: 374795
# Epoch: 2, Batch: 3, Train Loss: 1.254 Train Accuracy: 54.867%, Validation Loss: 1.233 Validation Accuracy: 55.460%
# Validation loss decreased (1.241262 --> 1.232988).  Saving model ...
# Performing Surgery for choice as 0.0818 for threshold 0.9642.
# Parameters are: 373837
# Epoch: 2, Batch: 4, Train Loss: 1.308 Train Accuracy: 55.697%, Validation Loss: 1.267 Validation Accuracy: 54.570%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.6803 for threshold 0.9636.
# Parameters are: 373073
# Epoch: 2, Batch: 5, Train Loss: 1.271 Train Accuracy: 55.531%, Validation Loss: 1.259 Validation Accuracy: 55.320%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.204 for threshold 0.9629.
# Parameters are: 372532
# Epoch: 2, Batch: 6, Train Loss: 1.314 Train Accuracy: 56.803%, Validation Loss: 1.202 Validation Accuracy: 57.130%
# Validation loss decreased (1.232988 --> 1.202054).  Saving model ...
# Performing Surgery for choice as 0.0285 for threshold 0.9622.
# Parameters are: 371927
# Epoch: 2, Batch: 7, Train Loss: 1.146 Train Accuracy: 57.522%, Validation Loss: 1.177 Validation Accuracy: 58.120%
# Validation loss decreased (1.202054 --> 1.177019).  Saving model ...
# Performing Surgery for choice as 0.4373 for threshold 0.9615.
# Parameters are: 371367
# Epoch: 2, Batch: 8, Train Loss: 1.150 Train Accuracy: 56.969%, Validation Loss: 1.196 Validation Accuracy: 56.540%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.4785 for threshold 0.9609.
# Parameters are: 370700
# Epoch: 2, Batch: 9, Train Loss: 1.194 Train Accuracy: 54.314%, Validation Loss: 1.220 Validation Accuracy: 55.440%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.533 for threshold 0.9602.
# Parameters are: 369922
# Epoch: 2, Batch: 10, Train Loss: 1.214 Train Accuracy: 56.748%, Validation Loss: 1.233 Validation Accuracy: 54.870%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.67 for threshold 0.9595.
# Parameters are: 369112
# Epoch: 2, Batch: 11, Train Loss: 1.202 Train Accuracy: 55.420%, Validation Loss: 1.230 Validation Accuracy: 55.370%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.79 for threshold 0.9589.
# Parameters are: 368285
# Epoch: 2, Batch: 12, Train Loss: 1.246 Train Accuracy: 56.914%, Validation Loss: 1.204 Validation Accuracy: 56.120%
# EarlyStopping counter: 5 out of 625
# Performing Surgery for choice as 0.9338 for threshold 0.9582.
# Parameters are: 367520
# Epoch: 2, Batch: 13, Train Loss: 1.221 Train Accuracy: 59.347%, Validation Loss: 1.165 Validation Accuracy: 57.890%
# Validation loss decreased (1.177019 --> 1.164931).  Saving model ...
# Performing Surgery for choice as 0.1869 for threshold 0.9575.
# Parameters are: 366728
# Epoch: 2, Batch: 14, Train Loss: 1.158 Train Accuracy: 59.015%, Validation Loss: 1.156 Validation Accuracy: 58.360%
# Validation loss decreased (1.164931 --> 1.155977).  Saving model ...
# Performing Surgery for choice as 0.7542 for threshold 0.9568.
# Parameters are: 365885
# Epoch: 2, Batch: 15, Train Loss: 1.146 Train Accuracy: 56.250%, Validation Loss: 1.177 Validation Accuracy: 57.140%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.7361 for threshold 0.9562.
# Parameters are: 364994
# Epoch: 2, Batch: 16, Train Loss: 1.228 Train Accuracy: 57.301%, Validation Loss: 1.181 Validation Accuracy: 56.690%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.4038 for threshold 0.9555.
# Parameters are: 364122
# Epoch: 2, Batch: 17, Train Loss: 1.212 Train Accuracy: 57.799%, Validation Loss: 1.158 Validation Accuracy: 57.720%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.075 for threshold 0.9548.
# Parameters are: 363199
# Epoch: 2, Batch: 18, Train Loss: 1.176 Train Accuracy: 56.692%, Validation Loss: 1.148 Validation Accuracy: 58.070%
# Validation loss decreased (1.155977 --> 1.148433).  Saving model ...
# Performing Surgery for choice as 0.3162 for threshold 0.9542.
# Parameters are: 362327
# Epoch: 2, Batch: 19, Train Loss: 1.141 Train Accuracy: 58.241%, Validation Loss: 1.157 Validation Accuracy: 57.930%
# EarlyStopping counter: 1 out of 625
# Parameters are: 362327
# Epoch: 2, Batch: 20, Train Loss: 1.079 Train Accuracy: 60.011%, Validation Loss: 1.166 Validation Accuracy: 57.920%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.909 for threshold 0.9528.
# Parameters are: 360901
# Epoch: 2, Batch: 21, Train Loss: 1.174 Train Accuracy: 58.075%, Validation Loss: 1.189 Validation Accuracy: 57.370%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.1416 for threshold 0.9522.
# Parameters are: 360267
# Epoch: 2, Batch: 22, Train Loss: 1.157 Train Accuracy: 58.296%, Validation Loss: 1.155 Validation Accuracy: 58.170%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.3756 for threshold 0.9515.
# Parameters are: 359658
# Epoch: 2, Batch: 23, Train Loss: 1.144 Train Accuracy: 59.237%, Validation Loss: 1.127 Validation Accuracy: 59.210%
# Validation loss decreased (1.148433 --> 1.127193).  Saving model ...
# Performing Surgery for choice as 0.5394 for threshold 0.9508.
# Parameters are: 358970
# Epoch: 2, Batch: 24, Train Loss: 1.101 Train Accuracy: 57.356%, Validation Loss: 1.135 Validation Accuracy: 58.620%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.8198 for threshold 0.9502.
# Parameters are: 358279
# Epoch: 2, Batch: 25, Train Loss: 1.124 Train Accuracy: 59.569%, Validation Loss: 1.147 Validation Accuracy: 58.100%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.7807 for threshold 0.9495.
# Parameters are: 357683
# Epoch: 2, Batch: 26, Train Loss: 1.103 Train Accuracy: 57.854%, Validation Loss: 1.147 Validation Accuracy: 58.110%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.7393 for threshold 0.9488.
# Parameters are: 357048
# Epoch: 2, Batch: 27, Train Loss: 1.109 Train Accuracy: 59.071%, Validation Loss: 1.146 Validation Accuracy: 58.650%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.6706 for threshold 0.9482.
# Parameters are: 356423
# Epoch: 2, Batch: 28, Train Loss: 1.150 Train Accuracy: 59.956%, Validation Loss: 1.145 Validation Accuracy: 59.120%
# EarlyStopping counter: 5 out of 625
# Performing Surgery for choice as 0.1066 for threshold 0.9475.
# Parameters are: 355840
# Epoch: 2, Batch: 29, Train Loss: 1.151 Train Accuracy: 59.900%, Validation Loss: 1.137 Validation Accuracy: 59.080%
# EarlyStopping counter: 6 out of 625
# Performing Surgery for choice as 0.2429 for threshold 0.9468.
# Parameters are: 355204
# Epoch: 2, Batch: 30, Train Loss: 1.081 Train Accuracy: 58.739%, Validation Loss: 1.126 Validation Accuracy: 59.700%
# Validation loss decreased (1.127193 --> 1.125601).  Saving model ...
# Performing Surgery for choice as 0.5422 for threshold 0.9462.
# Parameters are: 354450
# Epoch: 2, Batch: 31, Train Loss: 1.121 Train Accuracy: 60.509%, Validation Loss: 1.114 Validation Accuracy: 59.710%
# Validation loss decreased (1.125601 --> 1.114403).  Saving model ...
# Performing Surgery for choice as 0.1382 for threshold 0.9455.
# Parameters are: 353779
# Epoch: 2, Batch: 32, Train Loss: 1.103 Train Accuracy: 59.292%, Validation Loss: 1.131 Validation Accuracy: 59.150%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.5085 for threshold 0.9449.
# Parameters are: 353141
# Epoch: 2, Batch: 33, Train Loss: 1.136 Train Accuracy: 58.684%, Validation Loss: 1.154 Validation Accuracy: 58.450%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.1614 for threshold 0.9442.
# Parameters are: 352665
# Epoch: 2, Batch: 34, Train Loss: 1.243 Train Accuracy: 56.195%, Validation Loss: 1.133 Validation Accuracy: 59.280%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.2288 for threshold 0.9435.
# Parameters are: 352199
# Epoch: 2, Batch: 35, Train Loss: 1.093 Train Accuracy: 59.458%, Validation Loss: 1.095 Validation Accuracy: 60.410%
# Validation loss decreased (1.114403 --> 1.095462).  Saving model ...
# Performing Surgery for choice as 0.0659 for threshold 0.9429.
# Parameters are: 351755
# Epoch: 2, Batch: 36, Train Loss: 1.090 Train Accuracy: 60.232%, Validation Loss: 1.085 Validation Accuracy: 60.700%
# Validation loss decreased (1.095462 --> 1.084868).  Saving model ...
# Performing Surgery for choice as 0.2395 for threshold 0.9422.
# Parameters are: 351209
# Epoch: 2, Batch: 37, Train Loss: 1.053 Train Accuracy: 61.670%, Validation Loss: 1.113 Validation Accuracy: 60.280%
# EarlyStopping counter: 1 out of 625
# Parameters are: 351209
# Epoch: 2, Batch: 38, Train Loss: 1.061 Train Accuracy: 57.965%, Validation Loss: 1.121 Validation Accuracy: 60.130%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.4937 for threshold 0.9409.
# Parameters are: 350303
# Epoch: 2, Batch: 39, Train Loss: 1.097 Train Accuracy: 59.735%, Validation Loss: 1.130 Validation Accuracy: 59.810%
# EarlyStopping counter: 3 out of 625
# Parameters are: 350303
# Epoch: 2, Batch: 40, Train Loss: 1.111 Train Accuracy: 61.670%, Validation Loss: 1.100 Validation Accuracy: 60.470%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.6859 for threshold 0.9396.
# Parameters are: 349387
# Epoch: 2, Batch: 41, Train Loss: 1.112 Train Accuracy: 61.836%, Validation Loss: 1.078 Validation Accuracy: 60.800%
# Validation loss decreased (1.084868 --> 1.077758).  Saving model ...
# Performing Surgery for choice as 0.5619 for threshold 0.9389.
# Parameters are: 348854
# Epoch: 2, Batch: 42, Train Loss: 1.049 Train Accuracy: 62.002%, Validation Loss: 1.075 Validation Accuracy: 61.130%
# Validation loss decreased (1.077758 --> 1.075202).  Saving model ...
# Performing Surgery for choice as 0.2255 for threshold 0.9383.
# Parameters are: 348306
# Epoch: 2, Batch: 43, Train Loss: 1.016 Train Accuracy: 60.509%, Validation Loss: 1.098 Validation Accuracy: 60.310%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.7274 for threshold 0.9376.
# Parameters are: 347764
# Epoch: 2, Batch: 44, Train Loss: 1.085 Train Accuracy: 58.850%, Validation Loss: 1.128 Validation Accuracy: 59.140%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.5282 for threshold 0.937.
# Parameters are: 347298
# Epoch: 2, Batch: 45, Train Loss: 1.151 Train Accuracy: 60.785%, Validation Loss: 1.120 Validation Accuracy: 59.190%
# EarlyStopping counter: 3 out of 625
# Parameters are: 347298
# Epoch: 2, Batch: 46, Train Loss: 1.110 Train Accuracy: 60.841%, Validation Loss: 1.088 Validation Accuracy: 60.770%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.4942 for threshold 0.9356.
# Parameters are: 346429
# Epoch: 2, Batch: 47, Train Loss: 1.062 Train Accuracy: 61.338%, Validation Loss: 1.070 Validation Accuracy: 61.420%
# Validation loss decreased (1.075202 --> 1.070489).  Saving model ...
# Performing Surgery for choice as 0.7485 for threshold 0.935.
# Parameters are: 346021
# Epoch: 2, Batch: 48, Train Loss: 1.059 Train Accuracy: 60.122%, Validation Loss: 1.080 Validation Accuracy: 60.810%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.0453 for threshold 0.9343.
# Parameters are: 345604
# Epoch: 2, Batch: 49, Train Loss: 1.038 Train Accuracy: 60.177%, Validation Loss: 1.098 Validation Accuracy: 60.420%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.8803 for threshold 0.9337.
# Parameters are: 345220
# Epoch: 3, Batch: 1, Train Loss: 1.050 Train Accuracy: 60.066%, Validation Loss: 1.103 Validation Accuracy: 59.980%
# EarlyStopping counter: 3 out of 625
# Parameters are: 345220
# Epoch: 3, Batch: 2, Train Loss: 1.079 Train Accuracy: 61.449%, Validation Loss: 1.091 Validation Accuracy: 60.220%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.4776 for threshold 0.9324.
# Parameters are: 344654
# Epoch: 3, Batch: 3, Train Loss: 1.099 Train Accuracy: 60.841%, Validation Loss: 1.077 Validation Accuracy: 60.750%
# EarlyStopping counter: 5 out of 625
# Performing Surgery for choice as 0.0735 for threshold 0.9317.
# Parameters are: 344375
# Epoch: 3, Batch: 4, Train Loss: 1.095 Train Accuracy: 62.500%, Validation Loss: 1.060 Validation Accuracy: 61.520%
# Validation loss decreased (1.070489 --> 1.060313).  Saving model ...
# Performing Surgery for choice as 0.1845 for threshold 0.9311.
# Parameters are: 344066
# Epoch: 3, Batch: 5, Train Loss: 1.018 Train Accuracy: 62.113%, Validation Loss: 1.065 Validation Accuracy: 61.280%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.1974 for threshold 0.9304.
# Parameters are: 343740
# Epoch: 3, Batch: 6, Train Loss: 0.986 Train Accuracy: 61.394%, Validation Loss: 1.076 Validation Accuracy: 61.190%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.3095 for threshold 0.9298.
# Parameters are: 343409
# Epoch: 3, Batch: 7, Train Loss: 1.085 Train Accuracy: 61.007%, Validation Loss: 1.084 Validation Accuracy: 61.040%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.1327 for threshold 0.9291.
# Parameters are: 343067
# Epoch: 3, Batch: 8, Train Loss: 1.051 Train Accuracy: 59.956%, Validation Loss: 1.088 Validation Accuracy: 60.660%
# EarlyStopping counter: 4 out of 625
# Parameters are: 343067
# Epoch: 3, Batch: 9, Train Loss: 0.975 Train Accuracy: 62.279%, Validation Loss: 1.080 Validation Accuracy: 60.800%
# EarlyStopping counter: 5 out of 625
# Performing Surgery for choice as 0.8298 for threshold 0.9278.
# Parameters are: 342527
# Epoch: 3, Batch: 10, Train Loss: 1.053 Train Accuracy: 60.509%, Validation Loss: 1.068 Validation Accuracy: 61.300%
# EarlyStopping counter: 6 out of 625
# Performing Surgery for choice as 0.7543 for threshold 0.9272.
# Parameters are: 342245
# Epoch: 3, Batch: 11, Train Loss: 1.017 Train Accuracy: 62.777%, Validation Loss: 1.044 Validation Accuracy: 62.200%
# Validation loss decreased (1.060313 --> 1.044478).  Saving model ...
# Performing Surgery for choice as 0.3462 for threshold 0.9265.
# Parameters are: 341990
# Epoch: 3, Batch: 12, Train Loss: 0.985 Train Accuracy: 60.564%, Validation Loss: 1.039 Validation Accuracy: 62.380%
# Validation loss decreased (1.044478 --> 1.039286).  Saving model ...
# Performing Surgery for choice as 0.2578 for threshold 0.9259.
# Parameters are: 341676
# Epoch: 3, Batch: 13, Train Loss: 0.967 Train Accuracy: 61.670%, Validation Loss: 1.051 Validation Accuracy: 61.810%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.1141 for threshold 0.9252.
# Parameters are: 341301
# Epoch: 3, Batch: 14, Train Loss: 1.027 Train Accuracy: 61.228%, Validation Loss: 1.074 Validation Accuracy: 60.710%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.5918 for threshold 0.9246.
# Parameters are: 341040
# Epoch: 3, Batch: 15, Train Loss: 1.058 Train Accuracy: 61.670%, Validation Loss: 1.079 Validation Accuracy: 60.790%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.8798 for threshold 0.9239.
# Parameters are: 340804
# Epoch: 3, Batch: 16, Train Loss: 1.032 Train Accuracy: 63.330%, Validation Loss: 1.066 Validation Accuracy: 61.470%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.784 for threshold 0.9233.
# Parameters are: 340497
# Epoch: 3, Batch: 17, Train Loss: 1.036 Train Accuracy: 62.611%, Validation Loss: 1.045 Validation Accuracy: 62.350%
# EarlyStopping counter: 5 out of 625
# Performing Surgery for choice as 0.4244 for threshold 0.9226.
# Parameters are: 340137
# Epoch: 3, Batch: 18, Train Loss: 1.029 Train Accuracy: 61.781%, Validation Loss: 1.032 Validation Accuracy: 62.860%
# Validation loss decreased (1.039286 --> 1.032391).  Saving model ...
# Performing Surgery for choice as 0.4185 for threshold 0.922.
# Parameters are: 339720
# Epoch: 3, Batch: 19, Train Loss: 0.966 Train Accuracy: 62.777%, Validation Loss: 1.037 Validation Accuracy: 62.410%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.5831 for threshold 0.9213.
# Parameters are: 339274
# Epoch: 3, Batch: 20, Train Loss: 0.972 Train Accuracy: 60.675%, Validation Loss: 1.054 Validation Accuracy: 62.000%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.8367 for threshold 0.9207.
# Parameters are: 338872
# Epoch: 3, Batch: 21, Train Loss: 1.043 Train Accuracy: 62.058%, Validation Loss: 1.066 Validation Accuracy: 61.600%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.6548 for threshold 0.92.
# Parameters are: 338514
# Epoch: 3, Batch: 22, Train Loss: 0.974 Train Accuracy: 62.445%, Validation Loss: 1.063 Validation Accuracy: 61.790%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.2928 for threshold 0.9194.
# Parameters are: 338204
# Epoch: 3, Batch: 23, Train Loss: 1.063 Train Accuracy: 62.002%, Validation Loss: 1.045 Validation Accuracy: 62.440%
# EarlyStopping counter: 5 out of 625
# Performing Surgery for choice as 0.2201 for threshold 0.9188.
# Parameters are: 337911
# Epoch: 3, Batch: 24, Train Loss: 0.982 Train Accuracy: 62.279%, Validation Loss: 1.034 Validation Accuracy: 62.860%
# EarlyStopping counter: 6 out of 625
# Performing Surgery for choice as 0.6327 for threshold 0.9181.
# Parameters are: 337564
# Epoch: 3, Batch: 25, Train Loss: 0.997 Train Accuracy: 64.104%, Validation Loss: 1.027 Validation Accuracy: 62.930%
# Validation loss decreased (1.032391 --> 1.026896).  Saving model ...
# Performing Surgery for choice as 0.7566 for threshold 0.9175.
# Parameters are: 337242
# Epoch: 3, Batch: 26, Train Loss: 0.960 Train Accuracy: 61.670%, Validation Loss: 1.026 Validation Accuracy: 62.730%
# Validation loss decreased (1.026896 --> 1.026417).  Saving model ...
# Performing Surgery for choice as 0.092 for threshold 0.9168.
# Parameters are: 336932
# Epoch: 3, Batch: 27, Train Loss: 1.003 Train Accuracy: 63.274%, Validation Loss: 1.029 Validation Accuracy: 62.850%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.6126 for threshold 0.9162.
# Parameters are: 336606
# Epoch: 3, Batch: 28, Train Loss: 0.934 Train Accuracy: 61.892%, Validation Loss: 1.040 Validation Accuracy: 62.550%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.8466 for threshold 0.9155.
# Parameters are: 336322
# Epoch: 3, Batch: 29, Train Loss: 0.957 Train Accuracy: 62.389%, Validation Loss: 1.039 Validation Accuracy: 62.820%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.559 for threshold 0.9149.
# Parameters are: 336121
# Epoch: 3, Batch: 30, Train Loss: 0.974 Train Accuracy: 60.841%, Validation Loss: 1.029 Validation Accuracy: 63.190%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.7549 for threshold 0.9143.
# Parameters are: 335875
# Epoch: 3, Batch: 31, Train Loss: 0.979 Train Accuracy: 62.666%, Validation Loss: 1.018 Validation Accuracy: 63.250%
# Validation loss decreased (1.026417 --> 1.018294).  Saving model ...
# Performing Surgery for choice as 0.161 for threshold 0.9136.
# Parameters are: 335607
# Epoch: 3, Batch: 32, Train Loss: 0.985 Train Accuracy: 63.053%, Validation Loss: 1.014 Validation Accuracy: 63.310%
# Validation loss decreased (1.018294 --> 1.014022).  Saving model ...
# Performing Surgery for choice as 0.5712 for threshold 0.913.
# Parameters are: 335347
# Epoch: 3, Batch: 33, Train Loss: 0.974 Train Accuracy: 63.274%, Validation Loss: 1.016 Validation Accuracy: 63.170%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.3048 for threshold 0.9123.
# Parameters are: 335131
# Epoch: 3, Batch: 34, Train Loss: 0.997 Train Accuracy: 62.942%, Validation Loss: 1.018 Validation Accuracy: 63.300%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.5992 for threshold 0.9117.
# Parameters are: 334903
# Epoch: 3, Batch: 35, Train Loss: 0.986 Train Accuracy: 63.274%, Validation Loss: 1.019 Validation Accuracy: 63.400%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.1656 for threshold 0.9111.
# Parameters are: 334656
# Epoch: 3, Batch: 36, Train Loss: 1.033 Train Accuracy: 65.985%, Validation Loss: 1.015 Validation Accuracy: 63.500%
# EarlyStopping counter: 4 out of 625
# Parameters are: 334656
# Epoch: 3, Batch: 37, Train Loss: 1.022 Train Accuracy: 61.892%, Validation Loss: 1.011 Validation Accuracy: 63.550%
# Validation loss decreased (1.014022 --> 1.011046).  Saving model ...
# Performing Surgery for choice as 0.2898 for threshold 0.9098.
# Parameters are: 334098
# Epoch: 3, Batch: 38, Train Loss: 0.975 Train Accuracy: 65.210%, Validation Loss: 1.006 Validation Accuracy: 63.740%
# Validation loss decreased (1.011046 --> 1.005543).  Saving model ...
# Performing Surgery for choice as 0.5907 for threshold 0.9092.
# Parameters are: 333804
# Epoch: 3, Batch: 39, Train Loss: 0.999 Train Accuracy: 61.670%, Validation Loss: 1.005 Validation Accuracy: 63.550%
# Validation loss decreased (1.005543 --> 1.005224).  Saving model ...
# Performing Surgery for choice as 0.4162 for threshold 0.9085.
# Parameters are: 333485
# Epoch: 3, Batch: 40, Train Loss: 0.960 Train Accuracy: 63.606%, Validation Loss: 1.007 Validation Accuracy: 63.680%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.2796 for threshold 0.9079.
# Parameters are: 333207
# Epoch: 3, Batch: 41, Train Loss: 1.015 Train Accuracy: 64.215%, Validation Loss: 1.009 Validation Accuracy: 63.580%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.4369 for threshold 0.9073.
# Parameters are: 332960
# Epoch: 3, Batch: 42, Train Loss: 0.971 Train Accuracy: 61.892%, Validation Loss: 1.009 Validation Accuracy: 63.700%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.6731 for threshold 0.9066.
# Parameters are: 332713
# Epoch: 3, Batch: 43, Train Loss: 1.000 Train Accuracy: 65.431%, Validation Loss: 1.005 Validation Accuracy: 63.700%
# Validation loss decreased (1.005224 --> 1.004819).  Saving model ...
# Performing Surgery for choice as 0.2941 for threshold 0.906.
# Parameters are: 332503
# Epoch: 3, Batch: 44, Train Loss: 0.960 Train Accuracy: 65.155%, Validation Loss: 1.007 Validation Accuracy: 63.750%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.2182 for threshold 0.9053.
# Parameters are: 332268
# Epoch: 3, Batch: 45, Train Loss: 0.904 Train Accuracy: 64.104%, Validation Loss: 1.008 Validation Accuracy: 63.790%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.1074 for threshold 0.9047.
# Parameters are: 332054
# Epoch: 3, Batch: 46, Train Loss: 0.952 Train Accuracy: 64.159%, Validation Loss: 1.004 Validation Accuracy: 63.720%
# Validation loss decreased (1.004819 --> 1.003505).  Saving model ...
# Performing Surgery for choice as 0.1333 for threshold 0.9041.
# Parameters are: 331800
# Epoch: 3, Batch: 47, Train Loss: 0.933 Train Accuracy: 65.100%, Validation Loss: 0.998 Validation Accuracy: 63.720%
# Validation loss decreased (1.003505 --> 0.997705).  Saving model ...
# Performing Surgery for choice as 0.8965 for threshold 0.9034.
# Parameters are: 331560
# Epoch: 3, Batch: 48, Train Loss: 0.994 Train Accuracy: 63.274%, Validation Loss: 0.998 Validation Accuracy: 63.820%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.3068 for threshold 0.9028.
# Parameters are: 331300
# Epoch: 3, Batch: 49, Train Loss: 0.979 Train Accuracy: 62.887%, Validation Loss: 1.003 Validation Accuracy: 63.680%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.0758 for threshold 0.9022.
# Parameters are: 331056
# Epoch: 4, Batch: 1, Train Loss: 0.991 Train Accuracy: 60.785%, Validation Loss: 1.007 Validation Accuracy: 63.630%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.6801 for threshold 0.9016.
# Parameters are: 330868
# Epoch: 4, Batch: 2, Train Loss: 0.995 Train Accuracy: 63.053%, Validation Loss: 0.999 Validation Accuracy: 63.870%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.634 for threshold 0.9009.
# Parameters are: 330708
# Epoch: 4, Batch: 3, Train Loss: 0.930 Train Accuracy: 65.155%, Validation Loss: 0.996 Validation Accuracy: 63.970%
# Validation loss decreased (0.997705 --> 0.996499).  Saving model ...
# Performing Surgery for choice as 0.5002 for threshold 0.9003.
# Parameters are: 330537
# Epoch: 4, Batch: 4, Train Loss: 0.969 Train Accuracy: 64.270%, Validation Loss: 1.004 Validation Accuracy: 63.890%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.4094 for threshold 0.8997.
# Parameters are: 330376
# Epoch: 4, Batch: 5, Train Loss: 1.004 Train Accuracy: 64.768%, Validation Loss: 1.007 Validation Accuracy: 63.900%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.2012 for threshold 0.899.
# Parameters are: 330220
# Epoch: 4, Batch: 6, Train Loss: 0.961 Train Accuracy: 63.993%, Validation Loss: 0.996 Validation Accuracy: 64.230%
# Validation loss decreased (0.996499 --> 0.996475).  Saving model ...
# Performing Surgery for choice as 0.3256 for threshold 0.8984.
# Parameters are: 330061
# Epoch: 4, Batch: 7, Train Loss: 0.945 Train Accuracy: 63.330%, Validation Loss: 0.990 Validation Accuracy: 64.470%
# Validation loss decreased (0.996475 --> 0.989580).  Saving model ...
# Performing Surgery for choice as 0.1931 for threshold 0.8978.
# Parameters are: 329870
# Epoch: 4, Batch: 8, Train Loss: 0.939 Train Accuracy: 65.044%, Validation Loss: 0.996 Validation Accuracy: 63.880%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.4893 for threshold 0.8971.
# Parameters are: 329659
# Epoch: 4, Batch: 9, Train Loss: 0.888 Train Accuracy: 64.159%, Validation Loss: 1.005 Validation Accuracy: 63.490%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.1482 for threshold 0.8965.
# Parameters are: 329468
# Epoch: 4, Batch: 10, Train Loss: 0.914 Train Accuracy: 65.874%, Validation Loss: 1.002 Validation Accuracy: 63.680%
# EarlyStopping counter: 6 out of 625
# Performing Surgery for choice as 0.7596 for threshold 0.8878.
# Parameters are: 327053
# Epoch: 4, Batch: 24, Train Loss: 0.944 Train Accuracy: 63.385%, Validation Loss: 0.989 Validation Accuracy: 64.420%
# EarlyStopping counter: 7 out of 625
# Performing Surgery for choice as 0.5522 for threshold 0.8871.
# Parameters are: 326839
# Epoch: 4, Batch: 25, Train Loss: 1.000 Train Accuracy: 65.265%, Validation Loss: 0.991 Validation Accuracy: 64.480%
# EarlyStopping counter: 8 out of 625
# Performing Surgery for choice as 0.6855 for threshold 0.8865.
# Parameters are: 326608
# Epoch: 4, Batch: 26, Train Loss: 0.935 Train Accuracy: 64.159%, Validation Loss: 0.993 Validation Accuracy: 64.380%
# EarlyStopping counter: 9 out of 625
# Performing Surgery for choice as 0.6332 for threshold 0.8859.
# Parameters are: 326402
# Epoch: 4, Batch: 27, Train Loss: 0.908 Train Accuracy: 63.993%, Validation Loss: 0.987 Validation Accuracy: 64.560%
# EarlyStopping counter: 10 out of 625
# Performing Surgery for choice as 0.3697 for threshold 0.8853.
# Parameters are: 326214
# Epoch: 4, Batch: 28, Train Loss: 0.908 Train Accuracy: 66.427%, Validation Loss: 0.981 Validation Accuracy: 64.740%
# Validation loss decreased (0.982026 --> 0.980792).  Saving model ...
# Parameters are: 326214
# Epoch: 4, Batch: 29, Train Loss: 0.956 Train Accuracy: 64.546%, Validation Loss: 0.978 Validation Accuracy: 64.560%
# Validation loss decreased (0.980792 --> 0.978322).  Saving model ...
# Performing Surgery for choice as 0.2791 for threshold 0.884.
# Parameters are: 325902
# Epoch: 4, Batch: 30, Train Loss: 0.949 Train Accuracy: 64.934%, Validation Loss: 0.984 Validation Accuracy: 64.300%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.8391 for threshold 0.8834.
# Parameters are: 325691
# Epoch: 4, Batch: 31, Train Loss: 0.933 Train Accuracy: 64.104%, Validation Loss: 0.992 Validation Accuracy: 64.220%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.5767 for threshold 0.8828.
# Parameters are: 325466
# Epoch: 4, Batch: 32, Train Loss: 0.926 Train Accuracy: 64.270%, Validation Loss: 0.984 Validation Accuracy: 64.570%
# EarlyStopping counter: 3 out of 625
# Parameters are: 325466
# Epoch: 4, Batch: 33, Train Loss: 0.896 Train Accuracy: 64.712%, Validation Loss: 0.973 Validation Accuracy: 65.110%
# Validation loss decreased (0.978322 --> 0.972844).  Saving model ...
# Performing Surgery for choice as 0.5661 for threshold 0.8816.
# Parameters are: 325149
# Epoch: 4, Batch: 34, Train Loss: 0.876 Train Accuracy: 65.542%, Validation Loss: 0.976 Validation Accuracy: 64.890%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.3522 for threshold 0.881.
# Parameters are: 324978
# Epoch: 4, Batch: 35, Train Loss: 0.906 Train Accuracy: 64.934%, Validation Loss: 0.989 Validation Accuracy: 64.300%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.8006 for threshold 0.8803.
# Parameters are: 324832
# Epoch: 4, Batch: 36, Train Loss: 0.910 Train Accuracy: 64.104%, Validation Loss: 1.004 Validation Accuracy: 64.050%
# EarlyStopping counter: 3 out of 625
# Parameters are: 324832
# Epoch: 4, Batch: 37, Train Loss: 0.993 Train Accuracy: 64.049%, Validation Loss: 0.994 Validation Accuracy: 64.240%
# EarlyStopping counter: 4 out of 625
# Performing Surgery for choice as 0.6149 for threshold 0.8791.
# Parameters are: 324610
# Epoch: 4, Batch: 38, Train Loss: 0.956 Train Accuracy: 65.044%, Validation Loss: 0.976 Validation Accuracy: 64.950%
# EarlyStopping counter: 5 out of 625
# Performing Surgery for choice as 0.4434 for threshold 0.8785.
# Parameters are: 324481
# Epoch: 4, Batch: 39, Train Loss: 0.897 Train Accuracy: 64.934%, Validation Loss: 0.968 Validation Accuracy: 65.110%
# Validation loss decreased (0.972844 --> 0.967562).  Saving model ...
# Performing Surgery for choice as 0.3976 for threshold 0.8779.
# Parameters are: 324303
# Epoch: 4, Batch: 40, Train Loss: 0.881 Train Accuracy: 64.989%, Validation Loss: 0.976 Validation Accuracy: 64.760%
# EarlyStopping counter: 1 out of 625
# Performing Surgery for choice as 0.3394 for threshold 0.8773.
# Parameters are: 324159
# Epoch: 4, Batch: 41, Train Loss: 0.948 Train Accuracy: 64.159%, Validation Loss: 0.985 Validation Accuracy: 64.410%
# EarlyStopping counter: 2 out of 625
# Performing Surgery for choice as 0.1755 for threshold 0.8767.
# Parameters are: 324025
# Epoch: 4, Batch: 42, Train Loss: 0.921 Train Accuracy: 64.325%, Validation Loss: 0.982 Validation Accuracy: 64.540%
# EarlyStopping counter: 3 out of 625
# Performing Surgery for choice as 0.5728 for threshold 0.876.
# Parameters are: 323891
# Epoch: 4, Batch: 43, Train Loss: 0.941 Train Accuracy: 66.206%, Validation Loss: 0.971 Validation Accuracy: 64.880%
# EarlyStopping counter: 4 out of 625
# Parameters are: 323891
# Epoch: 4, Batch: 44, Train Loss: 0.884 Train Accuracy: 65.044%, Validation Loss: 0.968 Validation Accuracy: 65.220%
# EarlyStopping counter: 5 out of 625
# Performing Surgery for choice as 0.3987 for threshold 0.8748.
# Parameters are: 323581
# Epoch: 4, Batch: 45, Train Loss: 0.928 Train Accuracy: 63.717%, Validation Loss: 0.974 Validation Accuracy: 64.830%
# EarlyStopping counter: 6 out of 625
# Parameters are: 323581
# Epoch: 4, Batch: 46, Train Loss: 0.880 Train Accuracy: 64.270%, Validation Loss: 0.980 Validation Accuracy: 64.870%
# EarlyStopping counter: 7 out of 625
# Performing Surgery for choice as 0.5752 for threshold 0.8736.
# Parameters are: 323276
# Epoch: 4, Batch: 47, Train Loss: 0.893 Train Accuracy: 65.597%, Validation Loss: 0.984 Validation Accuracy: 64.840%
# EarlyStopping counter: 8 out of 625
# Performing Surgery for choice as 0.5569 for threshold 0.873.
# Parameters are: 323096
# Epoch: 4, Batch: 48, Train Loss: 0.907 Train Accuracy: 65.819%, Validation Loss: 0.989 Validation Accuracy: 64.640%
# Performing Surgery for choice as 0.2968 for threshold 0.4619.
# Parameters are: 294264
# Epoch: 23, Batch: 26, Train Loss: 0.774 Train Accuracy: 67.699%, Validation Loss: 0.896 Validation Accuracy: 68.150%
# EarlyStopping counter: 3 out of 625
# Parameters are: 294264
# Epoch: 23, Batch: 27, Train Loss: 0.760 Train Accuracy: 68.584%, Validation Loss: 0.895 Validation Accuracy: 68.150%
# EarlyStopping counter: 4 out of 625
# Parameters are: 294264
# Epoch: 23, Batch: 28, Train Loss: 0.759 Train Accuracy: 68.750%, Validation Loss: 0.895 Validation Accuracy: 68.160%
# EarlyStopping counter: 5 out of 625
# Parameters are: 294264
# Epoch: 23, Batch: 29, Train Loss: 0.736 Train Accuracy: 67.257%, Validation Loss: 0.896 Validation Accuracy: 68.180%
# EarlyStopping counter: 6 out of 625
# Performing Surgery for choice as 0.2454 for threshold 0.4606.
# Parameters are: 294228
# Epoch: 23, Batch: 30, Train Loss: 0.728 Train Accuracy: 66.538%, Validation Loss: 0.897 Validation Accuracy: 68.180%
# EarlyStopping counter: 7 out of 625
# Performing Surgery for choice as 0.2461 for threshold 0.4603.
# Parameters are: 294197
# Epoch: 23, Batch: 31, Train Loss: 0.823 Train Accuracy: 69.524%, Validation Loss: 0.895 Validation Accuracy: 68.120%
# EarlyStopping counter: 8 out of 625
# Performing Surgery for choice as 0.3519 for threshold 0.46.
# Parameters are: 294177
# Epoch: 23, Batch: 32, Train Loss: 0.784 Train Accuracy: 68.916%, Validation Loss: 0.895 Validation Accuracy: 68.100%
# EarlyStopping counter: 9 out of 625
# Performing Surgery for choice as 0.3191 for threshold 0.4597.
# Parameters are: 294140
# Epoch: 23, Batch: 33, Train Loss: 0.766 Train Accuracy: 67.920%, Validation Loss: 0.895 Validation Accuracy: 68.150%
# EarlyStopping counter: 10 out of 625
# Performing Surgery for choice as 0.4084 for threshold 0.4593.
# Parameters are: 294109
# Epoch: 23, Batch: 34, Train Loss: 0.790 Train Accuracy: 66.814%, Validation Loss: 0.896 Validation Accuracy: 68.110%
# EarlyStopping counter: 11 out of 625
# Parameters are: 294109
# Epoch: 23, Batch: 35, Train Loss: 0.785 Train Accuracy: 66.704%, Validation Loss: 0.897 Validation Accuracy: 68.100%
# EarlyStopping counter: 12 out of 625
# Performing Surgery for choice as 0.1392 for threshold 0.4587.
# Parameters are: 294082
# Epoch: 23, Batch: 36, Train Loss: 0.780 Train Accuracy: 68.584%, Validation Loss: 0.896 Validation Accuracy: 68.120%
# EarlyStopping counter: 13 out of 625
# Parameters are: 294082

# %%
pruned_model = deepcopy(model)
pruned_model.load_state_dict(torch.load(basepath+'/CheckPoints/'+'checkpoint_1.pt',map_location=lambda storage, loc: storage))
pruned_model = pruned_model.to(device)
print(pruned_model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=1024, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
get_model_layerwise_analysis(pruned_model)
# Out:
# tensor(0.2712, grad_fn=<MaxBackward1>) tensor(0.0907, grad_fn=<MeanBackward0>) tensor(0.0694, grad_fn=<StdBackward0>)
# tensor(0.1960, grad_fn=<MaxBackward1>) tensor(0.0101, grad_fn=<MeanBackward0>) tensor(0.0220, grad_fn=<StdBackward0>)
# tensor(0.2020, grad_fn=<MaxBackward1>) tensor(0.0025, grad_fn=<MeanBackward0>) tensor(0.0134, grad_fn=<StdBackward0>)
# tensor(0.2162, grad_fn=<MaxBackward1>) tensor(0.0011, grad_fn=<MeanBackward0>) tensor(0.0095, grad_fn=<StdBackward0>)
# tensor(0.1863, grad_fn=<MaxBackward1>) tensor(0.0020, grad_fn=<MeanBackward0>) tensor(0.0122, grad_fn=<StdBackward0>)
# tensor(0.1943, grad_fn=<MaxBackward1>) tensor(0.0006, grad_fn=<MeanBackward0>) tensor(0.0075, grad_fn=<StdBackward0>)
# tensor(0.1652, grad_fn=<MaxBackward1>) tensor(0.0008, grad_fn=<MeanBackward0>) tensor(0.0075, grad_fn=<StdBackward0>)
# tensor(0.1337, grad_fn=<MaxBackward1>) tensor(0.0072, grad_fn=<MeanBackward0>) tensor(0.0210, grad_fn=<StdBackward0>)

# %%
remaining_parameters = count_nonzeros(pruned_model)
print('For Compression without loss...')
print('Number of Initial Parameters are ' + str(initial_parameters))
print('Number of Remaining Parameters are ' + str(remaining_parameters))
print('Compression Rate without loss is ' + str(initial_parameters/remaining_parameters))
print('Best Accuracy is ' + str(round(best_accuracy*100,2)))
print('Best Loss is ' + str(round(best_loss,3)))
# Out:
# For Compression without loss...
# Number of Initial Parameters are 23272266
# Number of Remaining Parameters are 294320
# Compression Rate without loss is 79.0713033432998

# %%
def layer_wise_comparison(model,pruned_model):
  selected_layers = [0,2,4,6,8,10,12,14]
  model_layers = []
  for param in model.parameters():
    if param is not None: model_layers.append(torch.sum((param != 0).int()).item())
  
  pruned_model_layers = []
  for param in pruned_model.parameters():
    if param is not None: pruned_model_layers.append(torch.sum((param != 0).int()).item())

  for i in range(len(model_layers)):
    if i in selected_layers:
      print('Layer Parameters: ' + str(model_layers[i]) + ', Parameters Left: ' + str(pruned_model_layers[i]) + ', Percentage Left: ' + str(round(pruned_model_layers[i]*100/model_layers[i],2)))

print('For Compression without loss...')  
layer_wise_comparison(model,pruned_model)
# Out:
# For Compression without loss...
# Layer Parameters: 1728, Parameters Left: 1237, Percentage Left: 71.59
# Layer Parameters: 110592, Parameters Left: 21015, Percentage Left: 19.0
# Layer Parameters: 663552, Parameters Left: 24457, Percentage Left: 3.69
# Layer Parameters: 884736, Parameters Left: 11449, Percentage Left: 1.29
# Layer Parameters: 589824, Parameters Left: 16892, Percentage Left: 2.86
# Layer Parameters: 4194304, Parameters Left: 23624, Percentage Left: 0.56
# Layer Parameters: 16777215, Parameters Left: 181761, Percentage Left: 1.08
# Layer Parameters: 40960, Parameters Left: 4531, Percentage Left: 11.06

# %%
print('For Best Compression...')  
layer_wise_comparison(model,final_model)

# %%
print('Trained for '+str(last_parameter_size)+' non-zero parameters reaching '+str(initial_parameters/last_parameter_size)+' times compression with loss '+str(round(last_loss,3))+' and accuracy '+str(round(last_accuracy*100,2))+'%.')
